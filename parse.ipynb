# %%
import os
import re
import pandas as pd
import yaml
from metadata import get_china_province_code, get_china_city_code, get_china_area_name

def read_report(fp):
    with open(fp, "r") as f:
        return yaml.load(f, Loader=yaml.Loader)

def parse_int(text):
    if text:
        result = re.search("\\d+", text)
        if result:
            return result.group()

def parse_list(text, keys):
    if text:
        result = []
        for i in re.finditer("([\u4e00-\u9fa5]+)(\\d+)", text):
            result.append({
                keys[0]: i.group(1),
                keys[1]: i.group(2)
            })
        return result

def normalize_list(area_list, area_key):
    if area_key == "province":
        for x in area_list:
            name = x[area_key]
            x[area_key] = get_china_area_name(get_china_province_code(name), name)
    else:
        for x in area_list:
            name = x[area_key]
            x[area_key] = get_china_city_code(get_china_province_code(name), name)

def parse_report(report):
    date = str(report["时间"])
    area_key = "province"
    province = report.get("省")
    confirmed = parse_int(report.get("确诊"))
    suspected = parse_int(report.get("疑似"))
    cured = parse_int(report.get("治愈"))
    dead = parse_int(report.get("死亡"))
    area_key = "city" if province else "province"
    confirmed_list = parse_list(report.get("确诊详情"), [area_key, "confirmed"])
    suspected_list = parse_list(report.get("疑似详情"), [area_key, "suspected"])
    cured_list = parse_list(report.get("治愈详情"), [area_key, "cured"])
    dead_list = parse_list(report.get("死亡详情"), [area_key, "dead"])

    data = None
    if confirmed or suspected or cured or dead:
        data = {
            "confirmed": confirmed,
            "suspected": suspected,
            "cured": cured,
            "dead": dead
        }
        if province:
            data["provinceCode"] = get_china_province_code(province)
            data["province"] = get_china_area_name(data["provinceCode"], province)

    for data_list in [confirmed_list, suspected_list, cured_list, dead_list]:
        if data_list:
            for x in data_list:
                if province:
                    x["provinceCode"] = get_china_province_code(province)
                    x["province"] = get_china_area_name(x["provinceCode"], province)
                    x["cityCode"] = get_china_city_code(x["provinceCode"], x["city"])
                    x["city"] = get_china_area_name(x["cityCode"], x["city"])
                else:
                    x["provinceCode"] = get_china_province_code(x["province"])
                    x["province"] = get_china_area_name(x["provinceCode"], x["province"])

    df_list = [pd.DataFrame(x) for x in [confirmed_list, suspected_list, cured_list, dead_list] if x]
    df = None
    for index, x in enumerate(df_list):
        if df is None:
            df = x
        else:
            df = pd.merge(df, x, on=area_key, how="outer", suffixes=["", f"""_{index}"""], sort=False, copy=False)

    columns = ["date","country","countryCode","province","provinceCode","city","cityCode","confirmed","suspected","cured","dead"]
    if df is None:
        df = pd.DataFrame([data], columns=columns)
    else:
        df = pd.DataFrame(df, columns=columns)
        df = df.append([data])
    df["date"] = date
    df["country"] = "中国"
    df["countryCode"] = "CN"
    df["province"].fillna("", inplace=True)
    df["provinceCode"].fillna("", inplace=True)
    df["city"].fillna("", inplace=True)
    df["cityCode"].fillna("", inplace=True)
    df.sort_values(["date", "countryCode", "provinceCode", "cityCode"], inplace=True)
    return df

for r in os.listdir("Report"):
    report = read_report(os.path.join("Report", r))
    report_data = parse_report(report)
    report_data.to_csv(f"""ReportData/{report.get("时间")}{report.get("省", "")}.csv""", index=False)

# %%
import os
import pandas as pd

df_list = [pd.read_csv(os.path.join("ReportData", x)) for x in os.listdir("ReportData")]
df_list
# Out:
# N
#  15        NaN        1.0    NaN   NaN
#  16        1.0        NaN    NaN   NaN
#  17        1.0        NaN    NaN   NaN
#  18        2.0        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode  city  cityCode  \
#  0   2020-01-21      中国          CN      NaN           NaN   NaN       NaN
#  1   2020-01-21      中国          CN      北京市      110000.0   NaN       NaN
#  2   2020-01-21      中国          CN      天津市      120000.0   NaN       NaN
#  3   2020-01-21      中国          CN      山西省      140000.0   NaN       NaN
#  4   2020-01-21      中国          CN      吉林省      220000.0   NaN       NaN
#  5   2020-01-21      中国          CN     黑龙江省      230000.0   NaN       NaN
#  6   2020-01-21      中国          CN      上海市      310000.0   NaN       NaN
#  7   2020-01-21      中国          CN      浙江省      330000.0   NaN       NaN
#  8   2020-01-21      中国          CN      安徽省      340000.0   NaN       NaN
#  9   2020-01-21      中国          CN      江西省      360000.0   NaN       NaN
#  10  2020-01-21      中国          CN      山东省      370000.0   NaN       NaN
#  11  2020-01-21      中国          CN      河南省      410000.0   NaN       NaN
#  12  2020-01-21      中国          CN      湖北省      420000.0   NaN       NaN
#  13  2020-01-21      中国          CN      湖南省      430000.0   NaN       NaN
#  14  2020-01-21      中国          CN      广东省      440000.0   NaN       NaN
#  15  2020-01-21      中国          CN  广西壮族自治区      450000.0   NaN       NaN
#  16  2020-01-21      中国          CN      海南省      460000.0   NaN       NaN
#  17  2020-01-21      中国          CN      重庆市      500000.0   NaN       NaN
#  18  2020-01-21      中国          CN      四川省      510000.0   NaN       NaN
#  19  2020-01-21      中国          CN      贵州省      520000.0   NaN       NaN
#  20  2020-01-21      中国          CN      云南省      530000.0   NaN       NaN
#  21  2020-01-21      中国          CN  宁夏回族自治区      640000.0   NaN       NaN
#  22  2020-01-21      日本          JP      NaN           NaN   NaN       NaN
#  23  2020-01-21      韩国          KR      NaN           NaN   NaN       NaN
#  24  2020-01-21      泰国          TH      NaN           NaN   NaN       NaN
#
#      confirmed  suspected  cured  dead
#  0       440.0       37.0    NaN   9.0
#  1        10.0        NaN    NaN   NaN
#  2         2.0        NaN    NaN   NaN
#  3         NaN        1.0    NaN   NaN
#  4         NaN        1.0    NaN   NaN
#  5         NaN        1.0    NaN   NaN
#  6         9.0       10.0    NaN   NaN
#  7         5.0       10.0    NaN   NaN
#  8         NaN        3.0    NaN   NaN
#  9         2.0        NaN    NaN   NaN
#  10        1.0        NaN    NaN   NaN
#  11        1.0        NaN    NaN   NaN
#  12      375.0        NaN    NaN   9.0
#  13        1.0        NaN    NaN   NaN
#  14       26.0        1.0    NaN   NaN
#  15        NaN        2.0    NaN   NaN
#  16        NaN        1.0    NaN   NaN
#  17        5.0        NaN    NaN   NaN
#  18        2.0        5.0    NaN   NaN
#  19        NaN        1.0    NaN   NaN
#  20        1.0        NaN    NaN   NaN
#  21        NaN        1.0    NaN   NaN
#  22        1.0        NaN    NaN   NaN
#  23        1.0        NaN    NaN   NaN
#  24        3.0        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode  city  cityCode  \
#  0   2020-01-23      中国          CN      NaN           NaN   NaN       NaN
#  1   2020-01-23      中国          CN      河北省      130000.0   NaN       NaN
#  2   2020-01-23      中国          CN      湖北省      420000.0   NaN       NaN
#  3   2020-01-23      中国          CN      台湾省      710000.0   NaN       NaN
#  4   2020-01-23      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  5   2020-01-23      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#  6   2020-01-23      日本          JP      NaN           NaN   NaN       NaN
#  7   2020-01-23      韩国          KR      NaN           NaN   NaN       NaN
#  8   2020-01-23     新加坡          SG      NaN           NaN   NaN       NaN
#  9   2020-01-23      泰国          TH      NaN           NaN   NaN       NaN
#  10  2020-01-23      美国          US      NaN           NaN   NaN       NaN
#  11  2020-01-23      越南          VN      NaN           NaN   NaN       NaN
#
#      confirmed  suspected  cured  dead
#  0       830.0     1072.0   34.0  25.0
#  1         NaN        NaN    NaN   1.0
#  2         NaN        NaN    NaN  24.0
#  3         1.0        NaN    NaN   NaN
#  4         2.0        NaN    NaN   NaN
#  5         2.0        NaN    NaN   NaN
#  6         1.0        NaN    1.0   NaN
#  7         1.0        NaN    NaN   NaN
#  8         1.0        NaN    NaN   NaN
#  9         3.0        NaN    2.0   NaN
#  10        1.0        NaN    NaN   NaN
#  11        2.0        NaN    NaN   NaN  ,
#           date country countryCode province  provinceCode  city  cityCode  \
#  0  2020-01-22      中国          CN      湖北省        420000   NaN       NaN
#
#     confirmed  suspected  cured  dead
#  0        444        NaN     28    17  ,
#           date country countryCode province  provinceCode  city  cityCode  \
#  0  2020-01-22      中国          CN      NaN           NaN   NaN       NaN
#  1  2020-01-22      中国          CN      湖北省      420000.0   NaN       NaN
#  2  2020-01-22      中国          CN      台湾省      710000.0   NaN       NaN
#  3  2020-01-22      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  4  2020-01-22      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#  5  2020-01-22      日本          JP      NaN           NaN   NaN       NaN
#  6  2020-01-22      韩国          KR      NaN           NaN   NaN       NaN
#  7  2020-01-22      泰国          TH      NaN           NaN   NaN       NaN
#  8  2020-01-22      美国          US      NaN           NaN   NaN       NaN
#
#     confirmed  suspected  cured  dead
#  0      571.0      393.0    NaN  17.0
#  1        NaN        NaN    NaN  17.0
#  2        1.0        NaN    NaN   NaN
#  3        1.0        NaN    NaN   NaN
#  4        1.0        NaN    NaN   NaN
#  5        1.0        NaN    NaN   NaN
#  6        1.0        NaN    NaN   NaN
#  7        3.0        NaN    NaN   NaN
#  8        1.0        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode  city  cityCode  \
#  0   2020-01-26    澳大利亚          AU      NaN           NaN   NaN       NaN
#  1   2020-01-26      中国          CN      NaN           NaN   NaN       NaN
#  2   2020-01-26      中国          CN      台湾省      710000.0   NaN       NaN
#  3   2020-01-26      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  4   2020-01-26      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#  5   2020-01-26      法国          FR      NaN           NaN   NaN       NaN
#  6   2020-01-26      日本          JP      NaN           NaN   NaN       NaN
#  7   2020-01-26      韩国          KR      NaN           NaN   NaN       NaN
#  8   2020-01-26    马来西亚          MY      NaN           NaN   NaN       NaN
#  9   2020-01-26     尼泊尔          NP      NaN           NaN   NaN       NaN
#  10  2020-01-26     新加坡          SG      NaN           NaN   NaN       NaN
#  11  2020-01-26      泰国          TH      NaN           NaN   NaN       NaN
#  12  2020-01-26      美国          US      NaN           NaN   NaN       NaN
#  13  2020-01-26      越南          VN      NaN           NaN   NaN       NaN
#
#      confirmed  suspected  cured  dead
#  0           4        NaN    NaN   NaN
#  1        2744     5794.0   51.0  80.0
#  2           4        NaN    NaN   NaN
#  3           8        NaN    NaN   NaN
#  4           5        NaN    NaN   NaN
#  5           3        NaN    NaN   NaN
#  6           3        NaN    NaN   NaN
#  7           3        NaN    NaN   NaN
#  8           3        NaN    NaN   NaN
#  9           1        NaN    NaN   NaN
#  10          4        NaN    NaN   NaN
#  11          7        NaN    NaN   NaN
#  12          3        NaN    NaN   NaN
#  13          2        NaN    NaN   NaN  ,
#           date country countryCode province  provinceCode  city  cityCode  \
#  0  2020-01-20      中国          CN      湖北省        420000   NaN       NaN
#
#     confirmed  suspected  cured  dead
#  0        270        NaN     25     6  ,
#           date country countryCode province  provinceCode  city  cityCode  \
#  0  2020-01-27      中国          CN      NaN           NaN   NaN       NaN
#  1  2020-01-27      中国          CN      台湾省      710000.0   NaN       NaN
#  2  2020-01-27      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  3  2020-01-27      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#
#     confirmed  suspected  cured   dead
#  0       4515     6973.0   60.0  106.0
#  1          5        NaN    NaN    NaN
#  2          8        NaN    NaN    NaN
#  3          7        NaN    NaN    NaN  ,
#            date country countryCode province  provinceCode  city  cityCode  \
#  0   2020-01-25    澳大利亚          AU      NaN           NaN   NaN       NaN
#  1   2020-01-25      中国          CN      NaN           NaN   NaN       NaN
#  2   2020-01-25      中国          CN      台湾省      710000.0   NaN       NaN
#  3   2020-01-25      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  4   2020-01-25      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#  5   2020-01-25      法国          FR      NaN           NaN   NaN       NaN
#  6   2020-01-25      日本          JP      NaN           NaN   NaN       NaN
#  7   2020-01-25      韩国          KR      NaN           NaN   NaN       NaN
#  8   2020-01-25    马来西亚          MY      NaN           NaN   NaN       NaN
#  9   2020-01-25     尼泊尔          NP      NaN           NaN   NaN       NaN
#  10  2020-01-25     新加坡          SG      NaN           NaN   NaN       NaN
#  11  2020-01-25      泰国          TH      NaN           NaN   NaN       NaN
#  12  2020-01-25      美国          US      NaN           NaN   NaN       NaN
#  13  2020-01-25      越南          VN      NaN           NaN   NaN       NaN
#
#      confirmed  suspected  cured  dead
#  0           1        NaN    NaN   NaN
#  1        1975     2684.0   49.0  56.0
#  2           3        NaN    NaN   NaN
#  3           5        NaN    NaN   NaN
#  4           2        NaN    NaN   NaN
#  5           3        NaN    NaN   NaN
#  6           2        NaN    1.0   NaN
#  7           2        NaN    NaN   NaN
#  8           3        NaN    NaN   NaN
#  9           1        NaN    NaN   NaN
#  10          3        NaN    NaN   NaN
#  11          4        NaN    2.0   NaN
#  12          2        NaN    NaN   NaN
#  13          2        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode city  cityCode  \
#  0   2020-01-10      中国          CN      湖北省      420000.0  武汉市  420100.0
#  1   2020-01-11      中国          CN      湖北省      420000.0  武汉市  420100.0
#  2   2020-01-12      中国          CN      湖北省      420000.0  武汉市  420100.0
#  3   2020-01-13      中国          CN      湖北省      420000.0  武汉市  420100.0
#  4   2020-01-14      中国          CN      湖北省      420000.0  武汉市  420100.0
#  5   2020-01-15      中国          CN      湖北省      420000.0  武汉市  420100.0
#  6   2020-01-16      中国          CN      湖北省      420000.0  武汉市  420100.0
#  7   2020-01-16      日本          JP      NaN           NaN  NaN       NaN
#  8   2020-01-16      泰国          TH      NaN           NaN  NaN       NaN
#  9   2020-01-17      中国          CN      湖北省      420000.0  武汉市  420100.0
#  10  2020-01-18      中国          CN      湖北省      420000.0  武汉市  420100.0
#  11  2020-01-19      中国          CN      湖北省      420000.0  武汉市  420100.0
#
#      confirmed  suspected  cured  dead
#  0          41        NaN    2.0   1.0
#  1          41        NaN    6.0   1.0
#  2          41        NaN    7.0   1.0
#  3          41        NaN    7.0   1.0
#  4          41        NaN    7.0   1.0
#  5          41        NaN   12.0   2.0
#  6          45        NaN   15.0   2.0
#  7           1        NaN    NaN   NaN
#  8           1        NaN    NaN   NaN
#  9          62        NaN   19.0   2.0
#  10        121        NaN   24.0   3.0
#  11        198        NaN   25.0   3.0  ,
#            date country countryCode province  provinceCode  city  cityCode  \
#  0   2020-01-24      中国          CN      NaN           NaN   NaN       NaN
#  1   2020-01-24      中国          CN      河北省      130000.0   NaN       NaN
#  2   2020-01-24      中国          CN     黑龙江省      230000.0   NaN       NaN
#  3   2020-01-24      中国          CN      湖北省      420000.0   NaN       NaN
#  4   2020-01-24      中国          CN      台湾省      710000.0   NaN       NaN
#  5   2020-01-24      中国          CN  香港特别行政区      810000.0   NaN       NaN
#  6   2020-01-24      中国          CN  澳门特别行政区      820000.0   NaN       NaN
#  7   2020-01-24      法国          FR      NaN           NaN   NaN       NaN
#  8   2020-01-24      日本          JP      NaN           NaN   NaN       NaN
#  9   2020-01-24      韩国          KR      NaN           NaN   NaN       NaN
#  10  2020-01-24     尼泊尔          NP      NaN           NaN   NaN       NaN
#  11  2020-01-24     新加坡          SG      NaN           NaN   NaN       NaN
#  12  2020-01-24      泰国          TH      NaN           NaN   NaN       NaN
#  13  2020-01-24      美国          US      NaN           NaN   NaN       NaN
#  14  2020-01-24      越南          VN      NaN           NaN   NaN       NaN
#
#      confirmed  suspected  cured  dead
#  0      1287.0     1965.0   38.0  41.0
#  1         NaN        NaN    NaN   1.0
#  2         NaN        NaN    NaN   1.0
#  3         NaN        NaN    NaN  39.0
#  4         3.0        NaN    NaN   NaN
#  5         5.0        NaN    NaN   NaN
#  6         2.0        NaN    NaN   NaN
#  7         2.0        NaN    NaN   NaN
#  8         2.0        NaN    1.0   NaN
#  9         2.0        NaN    NaN   NaN
#  10        1.0        NaN    NaN   NaN
#  11        3.0        NaN    NaN   NaN
#  12        4.0        NaN    2.0   NaN
#  13        2.0        NaN    NaN   NaN
#  14        2.0        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode        city  \
#  0   2020-01-25      中国          CN      湖北省        420000         NaN
#  1   2020-01-25      中国          CN      湖北省        420000         武汉市
#  2   2020-01-25      中国          CN      湖北省        420000         黄石市
#  3   2020-01-25      中国          CN      湖北省        420000         十堰市
#  4   2020-01-25      中国          CN      湖北省        420000         宜昌市
#  5   2020-01-25      中国          CN      湖北省        420000         襄阳市
#  6   2020-01-25      中国          CN      湖北省        420000         鄂州市
#  7   2020-01-25      中国          CN      湖北省        420000         荆门市
#  8   2020-01-25      中国          CN      湖北省        420000         孝感市
#  9   2020-01-25      中国          CN      湖北省        420000         荆州市
#  10  2020-01-25      中国          CN      湖北省        420000         黄冈市
#  11  2020-01-25      中国          CN      湖北省        420000         咸宁市
#  12  2020-01-25      中国          CN      湖北省        420000         随州市
#  13  2020-01-25      中国          CN      湖北省        420000  恩施土家族苗族自治州
#  14  2020-01-25      中国          CN      湖北省        420000         仙桃市
#  15  2020-01-25      中国          CN      湖北省        420000         天门市
#
#      cityCode  confirmed  suspected  cured  dead
#  0        NaN       1052        NaN   42.0  52.0
#  1   420100.0        618        NaN   40.0  45.0
#  2   420200.0         31        NaN    NaN   1.0
#  3   420300.0         20        NaN    NaN   NaN
#  4   420500.0         20        NaN    NaN   1.0
#  5   420600.0          2        NaN    NaN   NaN
#  6   420700.0          1        NaN    NaN   NaN
#  7   420800.0         38        NaN    NaN   1.0
#  8   420900.0         55        NaN    NaN   NaN
#  9   421000.0         33        NaN    NaN   2.0
#  10  421100.0        122        NaN    2.0   2.0
#  11  421200.0         43        NaN    NaN   NaN
#  12  421300.0         36        NaN    NaN   NaN
#  13  422800.0         17        NaN    NaN   NaN
#  14  429004.0         11        NaN    NaN   NaN
#  15  429006.0          5        NaN    NaN   NaN  ,
#            date country countryCode province  provinceCode        city  \
#  0   2020-01-27      中国          CN      湖北省        420000         NaN
#  1   2020-01-27      中国          CN      湖北省        420000         武汉市
#  2   2020-01-27      中国          CN      湖北省        420000         黄石市
#  3   2020-01-27      中国          CN      湖北省        420000         十堰市
#  4   2020-01-27      中国          CN      湖北省        420000         宜昌市
#  5   2020-01-27      中国          CN      湖北省        420000         襄阳市
#  6   2020-01-27      中国          CN      湖北省        420000         鄂州市
#  7   2020-01-27      中国          CN      湖北省        420000         荆门市
#  8   2020-01-27      中国          CN      湖北省        420000         孝感市
#  9   2020-01-27      中国          CN      湖北省        420000         荆州市
#  10  2020-01-27      中国          CN      湖北省        420000         黄冈市
#  11  2020-01-27      中国          CN      湖北省        420000         咸宁市
#  12  2020-01-27      中国          CN      湖北省        420000         随州市
#  13  2020-01-27      中国          CN      湖北省        420000  恩施土家族苗族自治州
#  14  2020-01-27      中国          CN      湖北省        420000         仙桃市
#  15  2020-01-27      中国          CN      湖北省        420000         潜江市
#  16  2020-01-27      中国          CN      湖北省        420000         天门市
#  17  2020-01-27      中国          CN      湖北省        420000       神农架林区
#
#      cityCode  confirmed  suspected  cured   dead
#  0        NaN       2714        NaN   47.0  100.0
#  1   420100.0       1590        NaN    NaN   85.0
#  2   420200.0         53        NaN    NaN    1.0
#  3   420300.0         65        NaN    NaN    NaN
#  4   420500.0         51        NaN    NaN    1.0
#  5   420600.0         70        NaN    NaN    NaN
#  6   420700.0         57        NaN    NaN    NaN
#  7   420800.0        114        NaN    NaN    3.0
#  8   420900.0        173        NaN    NaN    1.0
#  9   421000.0         71        NaN    NaN    2.0
#  10  421100.0        213        NaN    NaN    4.0
#  11  421200.0         91        NaN    NaN    NaN
#  12  421300.0         70        NaN    NaN    NaN
#  13  422800.0         38        NaN    NaN    NaN
#  14  429004.0         27        NaN    NaN    NaN
#  15  429005.0          7        NaN    NaN    1.0
#  16  429006.0         23        NaN    NaN    2.0
#  17  429021.0          1        NaN    NaN    NaN  ,
#           date country countryCode province  provinceCode city  cityCode  \
#  0  2020-01-23      中国          CN      湖北省        420000  NaN       NaN
#  1  2020-01-23      中国          CN      湖北省        420000  武汉市  420100.0
#  2  2020-01-23      中国          CN      湖北省        420000  十堰市  420300.0
#  3  2020-01-23      中国          CN      湖北省        420000  宜昌市  420500.0
#  4  2020-01-23      中国          CN      湖北省        420000  荆门市  420800.0
#  5  2020-01-23      中国          CN      湖北省        420000  孝感市  420900.0
#  6  2020-01-23      中国          CN      湖北省        420000  荆州市  421000.0
#  7  2020-01-23      中国          CN      湖北省        420000  黄冈市  421100.0
#  8  2020-01-23      中国          CN      湖北省        420000  仙桃市  429004.0
#
#     confirmed  suspected  cured  dead
#  0        549        NaN   31.0  24.0
#  1        495        NaN    NaN   NaN
#  2          1        NaN    NaN   NaN
#  3          1        NaN    NaN   NaN
#  4          8        NaN    NaN   NaN
#  5         22        NaN    NaN   NaN
#  6          8        NaN    NaN   NaN
#  7         12        NaN    NaN   NaN
#  8          2        NaN    NaN   NaN  ,
#           date country countryCode province  provinceCode  city  cityCode  \
#  0  2020-01-21      中国          CN      湖北省        420000   NaN       NaN
#
#     confirmed  suspected  cured  dead
#  0        375        NaN     28     9  ]
